# %%
def conditional_probability(prob_a_and_b, prob_b):
  """
  Calculates the conditional probability of
  :param prob_a_and_b: P(A and B)
  :param prob_b: P(B)
  :return: P(A|B)
  """
  return prob_a_and_b / prob_b
  prob_a = 0.6
  prob_b = 0.4
  prob_a_and_b = 0.3
  prob_a_given_b = conditional_probability(prob_a_and_b, prob_b)
  print(prob_a_given_b)

# %%
# !apt-get install -qq -y fonts-nanum > /dev/null
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import numpy as np

# Find the installed font file
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
nanum_font_path = [f for f in font_list if 'NanumBarunGothic' in f]

if nanum_font_path:
    # Load the font properties
    font_properties = fm.FontProperties(fname=nanum_font_path[0])
    # Use the font in matplotlib
    matplotlib.rc("font", family=font_properties.get_name())

plt.rcParams['axes.unicode_minus'] = False
colors = ['#348ABD', "#A60628"]
prior = [1/25., 24/25]
posterior = [0.158, 1-0.158]
plt.bar([0, 1], prior, alpha=0.7, width=0.25,
        color=colors[0], label="사전확률",
        lw=3, edgecolor="#348ABD")
plt.bar([0+0.25, 1+0.25], posterior, alpha=0.7, width=0.25,
        color=colors[1], label="사후확률",
        lw=3, edgecolor='#A60628')
plt.xticks([0.125, 1.125],['가수', '직장인'])
plt.title('철수의직업에대한사전확률과사후확률')
plt.ylabel('확률')
plt.legend(loc='upper left')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
